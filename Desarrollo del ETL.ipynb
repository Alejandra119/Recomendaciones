# %% [markdown]
# # Desarrollo del Proyecto 1 - Recomendación de películas
# Hecho por: Alejandra Salas

# %% [markdown]
# ### Extract_Transform_Load (ETL)

# %% [markdown]
# ## 1. Extraer los datos de los archivos

# %%
# Se importan las librerías a usar.
import numpy as np
import pandas as pd
import json
import ast

# %%
# Cargamos los datos que se encuentran en archivo tipo ".csv" a un dataframe.
creditos = pd.read_csv('credits.csv',sep=',')
movies =pd.read_csv('movies_dataset.csv', sep=',',low_memory=False)

# %%
# Visualizamos los datos del dataframe "creditos".
creditos.sample(2)
# Out:
#                                                     cast
# 13501  [{'cast_id': 1, 'character': 'Ray Koval', 'cre...  \
# 21954  [{'cast_id': 1, 'character': 'Marcus', 'credit...
#
#                                                     crew     id
# 13501  [{'credit_id': '52fe46db9251416c75085cf9', 'de...  16558
# 21954  [{'credit_id': '591b1652925141061e066eab', 'de...  44745

# %%
# Visualizamos los datos del dataframe "movies".
movies.sample(2)
# Out:
#        adult belongs_to_collection budget
# 19171  False                   NaN      0  \
# 617    False                   NaN      0
#
#                                                   genres homepage     id
# 19171                                                 []      NaN  60003  \
# 617    [{'id': 35, 'name': 'Comedy'}, {'id': 53, 'nam...      NaN  28121
#
#          imdb_id original_language                     original_title
# 19171  tt0345852                en                          Red Rover  \
# 617    tt0117891                en  A Thin Line Between Love and Hate
#
#                                                 overview  ... release_date
# 19171  Two siblings played by William Baldin and Jodi...  ...   2006-10-08  \
# 617    Nightclub manager Darnell Wright is a perpetua...  ...   1996-04-04
#
#       revenue runtime                          spoken_languages    status
# 19171     0.0   103.0                                        []  Released  \
# 617       0.0   108.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                    tagline                              title
# 19171  A family. A legacy. A deadly curse.                          Red Rover  \
# 617                When you play, you pay.  A Thin Line Between Love and Hate
#
#        video vote_average vote_count
# 19171  False          4.7        3.0
# 617    False          5.7       15.0
#
# [2 rows x 24 columns]

# %% [markdown]
# ##### _Observaciones_
# Se observa que en las columnas "cast" y "crew" del dataframe "creditos", se encuentran anidadas en un formato diccionario. Así mismo, las columnas "belongs_to_collection", "genres", "production_companies", "production_countries" y "spoken_languages" del datraframe "movies", también se encuentran anidados en formato diccionario.

# %%
# Revisamos la información del dataframe "creditos" para conocer si cuneta con valores nulos.
creditos.info()
# Así mismo se puede observar los tipos de datos que contiene cada columna.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cast    45476 non-null  object
#  1   crew    45476 non-null  object
#  2   id      45476 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.0+ MB

# %%
# Revisamos la información del dataframe "movies" para conocer si cuneta con valores nulos.
movies.info()
# Si bien hay algunos datos nulos, no sería factible eliminarlos ya que podemos tener pocos datos a analizar.
# Así mismo se puede observar los tipos de datos que contiene cada columna.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
#  14  release_date           45379 non-null  object
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45460 non-null  object
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: float64(4), object(20)
# memory usage: 8.3+ MB

# %%
# Visualizamos la forma de la estructura del dataframe "creditos".
creditos.shape
# Tiene 45476 filas y 3 columnas.
# Out:
# (45476, 3)

# %%
# Visualizamos la forma de la estructura del dataframe "movies".
movies.shape
# Tiene 45466 filas y 24 columnas.
# Out:
# (45466, 24)

# %% [markdown]
# ## 2. Transformaciones de los dataframes

# %% [markdown]
# Algunos campos, como "cast" y "crew" del dataframe "creditos" y  "belongs_to_collection", "genres", "production_companies", "production_countries" y "spoken_languages" del datraframe "movies" están anidados, esto es o bien tienen un diccionario o una lista como valores en cada fila. Se desanidarán para poder utilizarlos y se unirán al dataset de nuevo para hacer alguna de las consultas de la API.

# %% [markdown]
# *Crew*

# %%
# Observamos el contenido de la columna "crew" del dataframe "creditos", en este contenido, necesitamos el nombre del "Director".
creditos['crew'].head(3).values
# Out:
# array(['[{\'credit_id\': \'52fe4284c3a36847f8024f49\', \'department\': \'Directing\', \'gender\': 2, \'id\': 7879, \'job\': \'Director\', \'name\': \'John Lasseter\', \'profile_path\': \'/7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f4f\', \'department\': \'Writing\', \'gender\': 2, \'id\': 12891, \'job\': \'Screenplay\', \'name\': \'Joss Whedon\', \'profile_path\': \'/dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f55\', \'department\': \'Writing\', \'gender\': 2, \'id\': 7, \'job\': \'Screenplay\', \'name\': \'Andrew Stanton\', \'profile_path\': \'/pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f5b\', \'department\': \'Writing\', \'gender\': 2, \'id\': 12892, \'job\': \'Screenplay\', \'name\': \'Joel Cohen\', \'profile_path\': \'/dAubAiZcvKFbboWlj7oXOkZnTSu.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f61\', \'department\': \'Writing\', \'gender\': 0, \'id\': 12893, \'job\': \'Screenplay\', \'name\': \'Alec Sokolow\', \'profile_path\': \'/v79vlRYi94BZUQnkkyznbGUZLjT.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f67\', \'department\': \'Production\', \'gender\': 1, \'id\': 12894, \'job\': \'Producer\', \'name\': \'Bonnie Arnold\', \'profile_path\': None}, {\'credit_id\': \'52fe4284c3a36847f8024f6d\', \'department\': \'Production\', \'gender\': 0, \'id\': 12895, \'job\': \'Executive Producer\', \'name\': \'Ed Catmull\', \'profile_path\': None}, {\'credit_id\': \'52fe4284c3a36847f8024f73\', \'department\': \'Production\', \'gender\': 2, \'id\': 12896, \'job\': \'Producer\', \'name\': \'Ralph Guggenheim\', \'profile_path\': None}, {\'credit_id\': \'52fe4284c3a36847f8024f79\', \'department\': \'Production\', \'gender\': 2, \'id\': 12897, \'job\': \'Executive Producer\', \'name\': \'Steve Jobs\', \'profile_path\': \'/mOMP3SwD5qWQSR0ldCIByd3guTV.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f8b\', \'department\': \'Editing\', \'gender\': 2, \'id\': 8, \'job\': \'Editor\', \'name\': \'Lee Unkrich\', \'profile_path\': \'/bdTCCXjgOV3YyaNmLGYGOxFQMOc.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f91\', \'department\': \'Art\', \'gender\': 2, \'id\': 7883, \'job\': \'Art Direction\', \'name\': \'Ralph Eggleston\', \'profile_path\': \'/uUfcGKDsKO1aROMpXRs67Hn6RvR.jpg\'}, {\'credit_id\': \'598331bf925141421201044b\', \'department\': \'Editing\', \'gender\': 2, \'id\': 1168870, \'job\': \'Editor\', \'name\': \'Robert Gordon\', \'profile_path\': None}, {\'credit_id\': \'5892168cc3a36809660095f9\', \'department\': \'Sound\', \'gender\': 0, \'id\': 1552883, \'job\': \'Foley Editor\', \'name\': \'Mary Helen Leasman\', \'profile_path\': None}, {\'credit_id\': \'5531824d9251415289000945\', \'department\': \'Visual Effects\', \'gender\': 0, \'id\': 1453514, \'job\': \'Animation\', \'name\': \'Kim Blanchette\', \'profile_path\': None}, {\'credit_id\': \'589215969251412dcb009bf6\', \'department\': \'Sound\', \'gender\': 0, \'id\': 1414182, \'job\': \'ADR Editor\', \'name\': \'Marilyn McCoppen\', \'profile_path\': None}, {\'credit_id\': \'589217099251412dc500a018\', \'department\': \'Sound\', \'gender\': 2, \'id\': 7885, \'job\': \'Orchestrator\', \'name\': \'Randy Newman\', \'profile_path\': \'/w0JzfoiM25nrnxYOzosPHRq6mlE.jpg\'}, {\'credit_id\': \'5693e6b29251417b0e0000e3\', \'department\': \'Editing\', \'gender\': 0, \'id\': 1429549, \'job\': \'Color Timer\', \'name\': \'Dale E. Grahn\', \'profile_path\': None}, {\'credit_id\': \'572e2522c3a36869e6001a9c\', \'department\': \'Visual Effects\', \'gender\': 0, \'id\': 7949, \'job\': \'CG Painter\', \'name\': \'Robin Cooper\', \'profile_path\': None}, {\'credit_id\': \'574f12309251415ca1000012\', \'department\': \'Writing\', \'gender\': 2, \'id\': 7879, \'job\': \'Original Story\', \'name\': \'John Lasseter\', \'profile_path\': \'/7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg\'}, {\'credit_id\': \'574f1240c3a3682e7300001c\', \'department\': \'Writing\', \'gender\': 2, \'id\': 12890, \'job\': \'Original Story\', \'name\': \'Pe ...
#        "[{'credit_id': '52fe466a9251416c75077a89', 'department': 'Directing', 'gender': 2, 'id': 26502, 'job': 'Director', 'name': 'Howard Deutch', 'profile_path': '/68Vae1HkU1NxQZ6KEmuxIpno7c9.jpg'}, {'credit_id': '52fe466b9251416c75077aa3', 'department': 'Writing', 'gender': 2, 'id': 16837, 'job': 'Characters', 'name': 'Mark Steven Johnson', 'profile_path': '/6trChNn3o2bi4i2ipgMEAytwmZp.jpg'}, {'credit_id': '52fe466b9251416c75077aa9', 'department': 'Writing', 'gender': 2, 'id': 16837, 'job': 'Writer', 'name': 'Mark Steven Johnson', 'profile_path': '/6trChNn3o2bi4i2ipgMEAytwmZp.jpg'}, {'credit_id': '5675eb4b92514179dd003933', 'department': 'Crew', 'gender': 2, 'id': 1551320, 'job': 'Sound Recordist', 'name': 'Jack Keller', 'profile_path': None}]"],
#       dtype=object)

# %%
# Extraemos el nombre del director de la columna "crew" del dataframe "creditos"
def extract_director(row):
    try:
        crew_list = ast.literal_eval(row['crew'])
        for crew_member in crew_list:
            if crew_member.get('job') == 'Director':
                return crew_member.get('name')
    except (SyntaxError, ValueError):
        pass
    return None

# Aplicamos la función para obtener el nombre del director
creditos['Director'] = creditos.apply(extract_director, axis=1)

creditos.head(5)
# Out:
#                                                 cast
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...  \
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id         Director
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862    John Lasseter
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844     Joe Johnston
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602    Howard Deutch
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357  Forest Whitaker
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862    Charles Shyer

# %%
# Comprobamos si los datos extraidos son correctos con los datos originales.
creditos['crew'].head(10).values
# Out:
# array(['[{\'credit_id\': \'52fe4284c3a36847f8024f49\', \'department\': \'Directing\', \'gender\': 2, \'id\': 7879, \'job\': \'Director\', \'name\': \'John Lasseter\', \'profile_path\': \'/7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f4f\', \'department\': \'Writing\', \'gender\': 2, \'id\': 12891, \'job\': \'Screenplay\', \'name\': \'Joss Whedon\', \'profile_path\': \'/dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f55\', \'department\': \'Writing\', \'gender\': 2, \'id\': 7, \'job\': \'Screenplay\', \'name\': \'Andrew Stanton\', \'profile_path\': \'/pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f5b\', \'department\': \'Writing\', \'gender\': 2, \'id\': 12892, \'job\': \'Screenplay\', \'name\': \'Joel Cohen\', \'profile_path\': \'/dAubAiZcvKFbboWlj7oXOkZnTSu.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f61\', \'department\': \'Writing\', \'gender\': 0, \'id\': 12893, \'job\': \'Screenplay\', \'name\': \'Alec Sokolow\', \'profile_path\': \'/v79vlRYi94BZUQnkkyznbGUZLjT.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f67\', \'department\': \'Production\', \'gender\': 1, \'id\': 12894, \'job\': \'Producer\', \'name\': \'Bonnie Arnold\', \'profile_path\': None}, {\'credit_id\': \'52fe4284c3a36847f8024f6d\', \'department\': \'Production\', \'gender\': 0, \'id\': 12895, \'job\': \'Executive Producer\', \'name\': \'Ed Catmull\', \'profile_path\': None}, {\'credit_id\': \'52fe4284c3a36847f8024f73\', \'department\': \'Production\', \'gender\': 2, \'id\': 12896, \'job\': \'Producer\', \'name\': \'Ralph Guggenheim\', \'profile_path\': None}, {\'credit_id\': \'52fe4284c3a36847f8024f79\', \'department\': \'Production\', \'gender\': 2, \'id\': 12897, \'job\': \'Executive Producer\', \'name\': \'Steve Jobs\', \'profile_path\': \'/mOMP3SwD5qWQSR0ldCIByd3guTV.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f8b\', \'department\': \'Editing\', \'gender\': 2, \'id\': 8, \'job\': \'Editor\', \'name\': \'Lee Unkrich\', \'profile_path\': \'/bdTCCXjgOV3YyaNmLGYGOxFQMOc.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f91\', \'department\': \'Art\', \'gender\': 2, \'id\': 7883, \'job\': \'Art Direction\', \'name\': \'Ralph Eggleston\', \'profile_path\': \'/uUfcGKDsKO1aROMpXRs67Hn6RvR.jpg\'}, {\'credit_id\': \'598331bf925141421201044b\', \'department\': \'Editing\', \'gender\': 2, \'id\': 1168870, \'job\': \'Editor\', \'name\': \'Robert Gordon\', \'profile_path\': None}, {\'credit_id\': \'5892168cc3a36809660095f9\', \'department\': \'Sound\', \'gender\': 0, \'id\': 1552883, \'job\': \'Foley Editor\', \'name\': \'Mary Helen Leasman\', \'profile_path\': None}, {\'credit_id\': \'5531824d9251415289000945\', \'department\': \'Visual Effects\', \'gender\': 0, \'id\': 1453514, \'job\': \'Animation\', \'name\': \'Kim Blanchette\', \'profile_path\': None}, {\'credit_id\': \'589215969251412dcb009bf6\', \'department\': \'Sound\', \'gender\': 0, \'id\': 1414182, \'job\': \'ADR Editor\', \'name\': \'Marilyn McCoppen\', \'profile_path\': None}, {\'credit_id\': \'589217099251412dc500a018\', \'department\': \'Sound\', \'gender\': 2, \'id\': 7885, \'job\': \'Orchestrator\', \'name\': \'Randy Newman\', \'profile_path\': \'/w0JzfoiM25nrnxYOzosPHRq6mlE.jpg\'}, {\'credit_id\': \'5693e6b29251417b0e0000e3\', \'department\': \'Editing\', \'gender\': 0, \'id\': 1429549, \'job\': \'Color Timer\', \'name\': \'Dale E. Grahn\', \'profile_path\': None}, {\'credit_id\': \'572e2522c3a36869e6001a9c\', \'department\': \'Visual Effects\', \'gender\': 0, \'id\': 7949, \'job\': \'CG Painter\', \'name\': \'Robin Cooper\', \'profile_path\': None}, {\'credit_id\': \'574f12309251415ca1000012\', \'department\': \'Writing\', \'gender\': 2, \'id\': 7879, \'job\': \'Original Story\', \'name\': \'John Lasseter\', \'profile_path\': \'/7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg\'}, {\'credit_id\': \'574f1240c3a3682e7300001c\', \'department\': \'Writing\', \'gender\': 2, \'id\': 12890, \'job\': \'Original Story\', \'name\': \'Pe ...
#        "[{'credit_id': '52fe44bfc3a36847f80a7cd1', 'department': 'Production', 'gender': 2, 'id': 511, 'job': 'Executive Producer', 'name': 'Larry J. Franco', 'profile_path': None}, {'credit_id': '52fe44bfc3a36847f80a7c89', 'department': 'Writing', 'gender': 2, 'id': 876, 'job': 'Screenplay', 'name': 'Jonathan Hensleigh', 'profile_path': '/l1c4UFD3g0HVWj5f0CxXAvMAGiT.jpg'}, {'credit_id': '52fe44bfc3a36847f80a7cdd', 'department': 'Sound', 'gender': 2, 'id': 1729, 'job': 'Original Music Composer', 'name': 'James Horner', 'profile_path': '/oLOtXxXsYk8X4qq0ud4xVypXudi.jpg'}, {'credit_id': '52fe44bfc3a36847f80a7c7d', 'department': 'Directing', 'gender': 2, 'id': 4945, 'job': 'Director', 'name': 'Joe Johnston', 'profile_path': '/fok4jaO62v5IP6hkpaaAcXuw2H.jpg'}, {'credit_id': '52fe44bfc3a36847f80a7cd7', 'department': 'Editing', 'gender': 2, 'id': 4951, 'job': 'Editor', 'name': 'Robert Dalva', 'profile_path': None}, {'credit_id': '573523bec3a368025100062c', 'department': 'Production', 'gender': 0, 'id': 4952, 'job': 'Casting', 'name': 'Nancy Foy', 'profile_path': '/blCkmS4dqNsbPGuQfozHE6wgWBw.jpg'}, {'credit_id': '5722a924c3a3682d1e000b41', 'department': 'Visual Effects', 'gender': 0, 'id': 8023, 'job': 'Animation Supervisor', 'name': 'Kyle Balda', 'profile_path': '/jR8iAP6uC0V42KbUG87qBIUO3Hj.jpg'}, {'credit_id': '52fe44c0c3a36847f80a7ce3', 'department': 'Art', 'gender': 2, 'id': 9967, 'job': 'Production Design', 'name': 'James D. Bissell', 'profile_path': None}, {'credit_id': '52fe44bfc3a36847f80a7cb9', 'department': 'Production', 'gender': 2, 'id': 9184, 'job': 'Producer', 'name': 'Scott Kroopf', 'profile_path': None}, {'credit_id': '52fe44bfc3a36847f80a7ccb', 'department': 'Production
\': \'Production\', \'gender\': 2, \'id\': 1254, \'job\': \'Producer\', \'name\': \'Art Linson\', \'profile_path\': \'/dEtVivCXxQBtIzmJcUNupT1AB4H.jpg\'}, {\'credit_id\': \'52fe4292c3a36847f802917f\', \'department\': \'Production\', \'gender\': 2, \'id\': 638, \'job\': \'Producer\', \'name\': \'Michael Mann\', \'profile_path\': \'/nKmUpRpuQIsYubR7vIxVKhkbaTW.jpg\'}, {\'credit_id\': \'52fe4292c3a36847f8029185\', \'department\': \'Sound\', \'gender\': 2, \'id\': 5581, \'job\': \'Original Music Composer\', \'name\': \'Elliot Goldenthal\', \'profile_path\': \'/mr1rr5bQySCwp564E1Ag363SgLH.jpg\'}, {\'credit_id\': \'52fe4292c3a36847f802918b\', \'department\': \'Camera\', \'gender\': 2, \'id\': 11099, \'job\': \'Director of Photography\', \'name\': \'Dante Spinotti\', \'profile_path\': \'/vIb3GU52BvSIQh1MXZRFDVRnqsm.jpg\'}, {\'credit_id\': \'52fe4292c3a36847f8029191\', \'department\': \'Editing\', \'gender\': 2, \'id\': 15840, \'job\': \'Editor\', \'name\': \'Pasquale Buba\', \'profile_path\': None}, {\'credit_id\': \'52fe4292c3a36847f8029197\', \'department\': \'Editing\', \'gender\': 0, \'id\': 15841, \'job\': \'Editor\', \'name\': \'William Goldenberg\', \'profile_path\': \'/eOgoea8HbZt2TfLn0tDNI1TepSN.jpg\'}, {\'credit_id\': \'52fe4292c3a36847f802919d\', \'department\': \'Editing\', \'gender\': 0, \'id\': 15842, \'job\': \'Editor\', \'name\': \'Dov Hoenig\', \'profile_path\': None}, {\'credit_id\': \'52fe4292c3a36847f80291a3\', \'department\': \'Editing\', \'gender\': 2, \'id\': 1047, \'job\': \'Editor\', \'name\': \'Tom Rolf\', \'profile_path\': None}, {\'credit_id\': \'52fe4292c3a36847f80291a9\', \'department\': \'Production\', \'gender\': 1, \'id\': 897, \'job\': \'Casting\', \'name\': \'Bonnie Timmermann\', \'profile_path\': \'/jM8QANtq0v7Eqy8ZYtKot27nsfK.jpg\'}, {\'credit_id\': \'52fe4292c3a36847f80291af\', \'department\': \'Art\', \'gender\': 2, \'id\': 11411, \'job\': \'Production Design\', \'name\': \'Neil Spisak\', \'profile_path\': None}, {\'credit_id\': \'52fe4292c3a36847f80291b5\', \'department\': \'Art\', \'gender\': 1, \'id\': 15843, \'job\': \'Art Direction\', \'name\': \'Margie Stone McShirley\', \'profile_path\': None}, {\'credit_id\': \'52fe4292c3a36847f80291bb\', \'department\': \'Costume & Make-Up\', \'gender\': 1, \'id\': 8527, \'job\': \'Costume Design\', \'name\': \'Deborah Lynn Scott\', \'profile_path\': None}, {\'credit_id\': \'52fe4292c3a36847f80291cd\', \'department\': \'Sound\', \'gender\': 2, \'id\': 1305, \'job\': \'Music Editor\', \'name\': \'Bill Abbott\', \'profile_path\': None}, {\'credit_id\': \'52fe4292c3a36847f80291d3\', \'department\': \'Sound\', \'gender\': 0, \'id\': 14765, \'job\': \'Supervising Sound Editor\', \'name\': \'Per Hallberg\', \'profile_path\': None}, {\'credit_id\': \'52fe4292c3a36847f80291d9\', \'department\': \'Crew\', \'gender\': 0, \'id\': 15847, \'job\': \'Special Effects Coordinator\', \'name\': \'Terry D. Frazee\', \'profile_path\': None}, {\'credit_id\': \'52fe4292c3a36847f80291df\', \'department\': \'Crew\', \'gender\': 0, \'id\': 15848, \'job\': \'Special Effects\', \'name\': \'Paul H. Haines Jr.\', \'profile_path\': None}, {\'credit_id\': \'52fe4292c3a36847f80291e5\', \'department\': \'Visual Effects\', \'gender\': 0, \'id\': 15849, \'job\': \'Visual Effects Supervisor\', \'name\': \'Neil Krepela\', \'profile_path\': None}, {\'credit_id\': \'52fe4292c3a36847f80291eb\', \'department\': \'Crew\', \'gender\': 2, \'id\': 13458, \'job\': \'Stunt Coordinator\', \'name\': \'Joel Kramer\', \ ...
#        "[{'credit_id': '52fe44959251416c75039da9', 'department': 'Directing', 'gender': 2, 'id': 2226, 'job': 'Director', 'name': 'Sydney Pollack', 'profile_path': '/zxkoU2diKtvarV1Qk4z9He2lJj9.jpg'}, {'credit_id': '52fe44959251416c75039daf', 'department': 'Writing', 'gender': 1, 'id': 70846, 'job': 'Screenplay', 'name': 'Barbara Benedek', 'profile_path': None}, {'credit_id': '52fe44959251416c75039db5', 'department': 'Production', 'gender': 2, 'id': 2226, 'job': 'Producer', 'name': 'Sydney Pollack', 'profile_path': '/zxkoU2diKtvarV1Qk4z9He2lJj9.jpg'}, {'credit_id': '52fe44959251416c75039dbb', 'department': 'Sound', 'gender': 2, 'id': 491, 'job': 'Original Music Composer', 'name': 'John Williams', 'profile_path': '/2Ats98PB1SH2yfEPikiLdhRuXZm.jpg'}, {'credit_id': '52fe44959251416c75039dc7', 'department': 'Editing', 'gender': 2, 'id': 10640, 'job': 'Editor', 'name': 'Fredric Steinkamp', 'profile_path': None}, {'credit_id': '55a3b9c2c3a3681ce30058b3', 'department': 'Production', 'gender': 2, 'id': 2997, 'job': 'Producer', 'name': 'Scott Rudin', 'profile_path': '/zR8sdlGblto6dneAr2mckTowwEl.jpg'}, {'credit_id': '55a3ba349251412974005664', 'department': 'Production', 'gender': 2, 'id': 5490, 'job': 'Casting', 'name': 'David Rubin', 'profile_path': '/x22xlcu30x5s8jelEIkJVBeLHrn.jpg'}, {'credit_id': '569cf5c89251415e7000342f', 'department': 'Art', 'gender': 2, 'id': 1718, 'job': 'Production Design', 'name': 'Brian Morris', 'profile_path': None}, {'credit_id': '569cfb339251415e5e0033b3', 'department': 'Writing', 'gender': 2, 'id': 11056, 'job': 'Screenplay', 'name': 'David Rayfiel', 'profile_path': None}, {'credit_id': '569cf55ec3a36858e500357c', 'department': 'Costume & Make-Up', 'gender': 2, 'id': 10199, 'job': 'Makeup Artist', 'name': 'Peter Robb-King', 'profile_path': None}, {'credit_id': '569cf57c9251415e730030f4', 'department': 'Costume & Make-Up', 'gender': 0, 'id': 142152, 'job': 'Makeup Artist', 'name': 
info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   cast      45476 non-null  object
#  1   crew      45476 non-null  object
#  2   id        45476 non-null  int64
#  3   Director  44589 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.4+ MB

# %% [markdown]
# *Belongs_to_collection*

# %%
# Utilizamos ast.literal_eval para evaluar la columna 'belongs_to_collection' como un diccionario de Python
movies['belongs_to_collection'] = movies['belongs_to_collection'].apply(lambda x: ast.literal_eval(x) if pd.notnull(x) else 'None')

# Extraemos el nombre de la colección
movies['collection_name'] = movies['belongs_to_collection'].apply(lambda x: x.get('name', '') if isinstance(x, dict) else 'None')

# Imprimimos movies con la columna normalizada
movies.sample(5)
# Out:
#        adult belongs_to_collection   budget
# 24634  False                  None        0  \
# 44304  False                  None        0
# 41596  False                  None  7000000
# 15001  False                  None        0
# 8922   False                  None    25000
#
#                                                   genres
# 24634                      [{'id': 18, 'name': 'Drama'}]  \
# 44304                     [{'id': 35, 'name': 'Comedy'}]
# 41596                      [{'id': 18, 'name': 'Drama'}]
# 15001                      [{'id': 18, 'name': 'Drama'}]
# 8922   [{'id': 14, 'name': 'Fantasy'}, {'id': 27, 'na...
#
#                                      homepage      id    imdb_id
# 24634                                     NaN  289314  tt3012698  \
# 44304                                     NaN  249233  tt3499286
# 41596  http://www.20thcenturywomen-movie.com/  342737  tt4385888
# 15001             http://www.kuuki-ningyo.com   25053  tt1371630
# 8922                                      NaN   41967  tt0096218
#
#       original_language                        original_title
# 24634                en                      Olive Kitteridge  \
# 44304                en  Anjelah Johnson: The Homecoming Show
# 41596                en                    20th Century Women
# 15001                ja                                  空気人形
# 8922                 en         Tales from the Gimli Hospital
#
#                                                 overview  ...    revenue
# 24634  The story focuses on a middle-school math teac...  ...        0.0  \
# 44304  Former Raiders cheerleader turned stand-up com...  ...        0.0
# 41596  In 1979 Santa Barbara, California, Dorothea Fi...  ...  5816211.0
# 15001  An "air doll" suddenly come to life one day. W...  ...        0.0
# 8922   While their mother is dying in the modern Giml...  ...        0.0
#
#       runtime                                   spoken_languages    status
# 24634   233.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released  \
# 44304    60.0                                                 []  Released
# 41596   119.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 15001   125.0               [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# 8922     68.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                              tagline
# 24634        There's no such thing as a simple life.  \
# 44304                                            NaN
# 41596                                            NaN
# 15001                                            NaN
# 8922   It all happened in a Gimli we no longer know.
#
#                                       title  video vote_average vote_count
# 24634                      Olive Kitteridge  False          7.6       66.0  \
# 44304  Anjelah Johnson: The Homecoming Show  False          4.0        1.0
# 41596                    20th Century Women  False          7.3      213.0
# 15001                              Air Doll  False          6.6       53.0
# 8922          Tales from the Gimli Hospital  False          7.4        6.0
#
#       collection_name
# 24634            None
# 44304            None
# 41596            None
# 15001            None
# 8922             None
#
# [5 rows x 25 columns]

# %% [markdown]
# *Genres*

# %%
# Utilizamos ast.literal_eval para evaluar la columna 'genres' como un diccionario de Python
movies['genres'] = movies['genres'].apply(lambda x: ast.literal_eval(x) if pd.notnull(x) else 'None')
        
# Extraemos los nombres de los géneros con una función
def extract_genre_names(genres_list):
    genre_names = [genre['name'] for genre in genres_list]
    return ', '.join(genre_names)

# Aplicamos la función a cada elemento de la columna 'genres'
movies['genre'] = movies['genres'].apply(extract_genre_names)

# Imprimimos el DataFrame con la columna de géneros normalizados
movies.sample(5)
# Out:
#        adult belongs_to_collection  budget
# 507    False                  None       0  \
# 43372  False                  None  950000
# 276    False                  None       0
# 34383  False                  None       0
# 18523  False                  None       0
#
#                                                   genres homepage     id
# 507    [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...      NaN  25557  \
# 43372  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...      NaN  30593
# 276    [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...      NaN   8438
# 34383  [{'id': 14, 'name': 'Fantasy'}, {'id': 16, 'na...      NaN  65592
# 18523                     [{'id': 35, 'name': 'Comedy'}]      NaN  79133
#
#          imdb_id original_language           original_title
# 507    tt0111003                en       The Puppet Masters  \
# 43372  tt0070165                en            Heavy Traffic
# 276    tt0113870                en      Murder in the First
# 34383  tt0229664                fr    Princes et princesses
# 18523  tt2114375                en  Dylan Moran: Yeah, Yeah
#
#                                                 overview  ... runtime
# 507    The Earth is invaded by alien parasites aka "s...  ...   109.0  \
# 43372  An "underground" cartoonist contends with life...  ...    76.0
# 276    Inspired by a true story. A petty criminal sen...  ...   122.0
# 34383  This is a very fantastic and different world a...  ...    70.0
# 18523  Dylan Moran, star of Black Books, Shaun of the...  ...    73.0
#
#                                         spoken_languages    status
# 507             [{'iso_639_1': 'en', 'name': 'English'}]  Released  \
# 43372  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 276             [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 34383          [{'iso_639_1': 'fr', 'name': 'Français'}]  Released
# 18523           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                             tagline                    title
# 507                                    Trust No One       The Puppet Masters  \
# 43372  More Spice from the makers of Fritz the Cat!            Heavy Traffic
# 276            The trial that brought down Alcatraz      Murder in the First
# 34383                                           NaN   Princes and Princesses
# 18523                                           NaN  Dylan Moran: Yeah, Yeah
#
#        video  vote_average vote_count collection_name
# 507    False           5.6       41.0            None  \
# 43372  False           6.6       18.0            None
# 276    False           6.9      140.0            None
# 34383  False           7.6       25.0            None
# 18523  False           7.5        9.0            None
#
#                                                    genre
# 507                    Horror, Science Fiction, Thriller
# 43372                           Animation, Comedy, Drama
# 276                                         Crime, Drama
# 34383  Fantasy, Animation, Drama, Science Fiction, Ro...
# 18523                                             Comedy
#
# [5 rows x 26 columns]

# %%
# Cambiamos los campos vacíos de las columnas "genres"  y "genre" por "None" en el daraframe "movies".
movies['genres'] = movies['genres'].apply(lambda x: 'None' if x == [] else x)
movies['genre'] = movies['genre'].apply(lambda x: 'None' if x == '' else x)

# %%
movies['genres'][55]
# Out:
# 'None'

# %%
# Comprobamos que estos valores estén con la palabra "None".
movies.sample(3)
# Out:
#        adult belongs_to_collection    budget
# 39234  False                  None         0  \
# 26794  False                  None         0
# 14860  False                  None  14000000
#
#                                                   genres
# 39234  [{'id': 53, 'name': 'Thriller'}, {'id': 10770,...  \
# 26794                      [{'id': 18, 'name': 'Drama'}]
# 14860  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
#
#                                                 homepage      id    imdb_id
# 39234  http://www.mylifetime.com/movies/mother-may-i-...  399747  tt5480528  \
# 26794                                                NaN  129251  tt0099842
# 14860                                                NaN   12273  tt1146325
#
#       original_language                    original_title
# 39234                en  Mother, May I Sleep with Danger?  \
# 26794                en                      The Incident
# 14860                hi                    Singh Is Kinng
#
#                                                 overview  ... runtime
# 39234  When theater major Leah, brings home the speci...  ...    86.0  \
# 26794  Small town lawyer, Harmon Cobb, defends a Nazi...  ...   100.0
# 14860  A comic caper about Happy Singh, a Punjabi vil...  ...   135.0
#
#                                         spoken_languages    status
# 39234           [{'iso_639_1': 'en', 'name': 'English'}]  Released  \
# 26794           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 14860  [{'iso_639_1': 'hi', 'name': 'हिन्दी'}, {'iso_...  Released
#
#                                                  tagline
# 39234                                                NaN  \
# 26794                                         Small Town
# 14860  Summer 2008: The gang of Punjab arrives with a...
#
#                                   title  video  vote_average vote_count
# 39234  Mother, May I Sleep with Danger?  False           5.4       15.0  \
# 26794                      The Incident  False           4.8        4.0
# 14860                    Singh Is Kinng  False           5.3       22.0
#
#       collection_name               genre
# 39234            None  Thriller, TV Movie
# 26794            None               Drama
# 14860            None      Action, Comedy
#
# [3 rows x 26 columns]

# %% [markdown]
# *Production_companies*

# %%
# Realizamos una función para normalizar la columna 'production_companies'
def normalize_production_companies(companies_list):
    if isinstance(companies_list, list):  # Si ya es una lista, asumimos que los datos están correctamente formateados
        company_names = [company['name'] for company in companies_list]
        return ', '.join(company_names)
    else:  # Si no es una lista, utilizamos ast.literal_eval para convertir la cadena JSON en una lista
        try:
            companies_list = ast.literal_eval(companies_list)
            if isinstance(companies_list, list):
                company_names = [company['name'] for company in companies_list]
                return ', '.join(company_names)
            else:
                return 'None'
        except (SyntaxError, ValueError):
            return 'None'

# Aplicamos la función a cada elemento de la columna 'production_companies'
movies['company'] = movies['production_companies'].apply(normalize_production_companies)

# Imprimimos movies con la columna de compañías de producción normalizada
movies.sample(5)
# Out:
#        adult belongs_to_collection     budget
# 41811  False                  None          0  \
# 26311  False                  None          0
# 22979  False                  None  145000000
# 34872  False                  None          0
# 15587  False                  None          0
#
#                                                   genres homepage      id
# 41811  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...      NaN  308919  \
# 26311  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...      NaN  107999
# 22979  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...      NaN   82703
# 34872                     [{'id': 35, 'name': 'Comedy'}]      NaN  172443
# 15587  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...      NaN   61430
#
#          imdb_id original_language             original_title
# 41811  tt3627780                en         Wishin' and Hopin'  \
# 26311  tt0040187                en        The Bride Goes Wild
# 22979  tt0864835                en      Mr. Peabody & Sherman
# 34872  tt0006809                en  His Picture in the Papers
# 15587  tt0044331                en         Affair in Trinidad
#
#                                                 overview  ...
# 41811  Based on the New York Times best-selling novel...  ...  \
# 26311  McGrath publishes books for children and Uncle...  ...
# 22979  A young boy and his dog, who happens to have a...  ...
# 34872  A young man can only get the woman he loves if...  ...
# 15587  A nightclub singer enlists her brother-in-law ...  ...
#
#                                 spoken_languages    status
# 41811  [{'iso_639_1': 'fr', 'name': 'Français'}]  Released  \
# 26311   [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 22979   [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 34872                                         []  Released
# 15587   [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline
# 41811                                                NaN  \
# 26311                                                NaN
# 22979                   He's Leaving His Mark On History
# 34872                                                NaN
# 15587  "You weren't the first... and you won't be the...
#
#                            title  video  vote_average  vote_count
# 41811         Wishin' and Hopin'  False           4.0         1.0  \
# 26311        The Bride Goes Wild  False           6.0         1.0
# 22979      Mr. Peabody & Sherman  False           6.7       861.0
# 34872  His Picture in the Papers  False           4.0         1.0
# 15587         Affair in Trinidad  False           6.3         5.0
#
#       collection_name                         genre
# 41811            None                 Drama, Comedy  \
# 26311            None               Comedy, Romance
# 22979            None  Animation, Adventure, Family
# 34872            None                        Comedy
# 15587            None    Thriller, Mystery, Romance
#
#                                                  company
# 41811  Synthetic Cinema International, Flavorlab, Sta...
# 26311                          Metro-Goldwyn-Mayer (MGM)
# 22979  Pacific Data Images (PDI), DreamWorks Animatio...
# 34872                             Fine Arts Film Company
# 15587  Columbia Pictures Corporation, The Beckworth C...
#
# [5 rows x 27 columns]

# %%
# Cambiamos los campos vacíos de las columnas "genres"  y "genre" por "None" en el daraframe "movies".
movies['production_companies']= movies['production_companies'].apply(lambda x: 'None' if x == '[]' else x)
movies['company'] = movies['company'].apply(lambda x: 'None' if x == '' else x)

# %% [markdown]
# *Production_countries*

# %%
# Aseguramos que la columna 'production_countries' contenga datos JSON válidos
movies['production_countries'] = movies['production_countries'].apply(lambda x: ast.literal_eval(x) if pd.notnull(x) else 'None')

# Realizamos una función para normalizar la columna 'production_countries'
def normalize_production_countries(countries_list):
    if isinstance(countries_list, list):
        country_names = [country['name'] for country in countries_list]
        return ', '.join(country_names)
    else:
        return 'None'

# Aplicamos la función a cada elemento de la columna 'production_countries'
movies['country'] = movies['production_countries'].apply(normalize_production_countries)

# Imprimimos movies con la columna de países de producción normalizada
movies.sample(5)
# Out:
#        adult                              belongs_to_collection    budget
# 22866  False                                               None         0  \
# 19359  False                                               None  17000000
# 11047  False                                               None         0
# 5358   False                                               None         0
# 11372  False  {'id': 52749, 'name': 'The Butterfly Effect Co...         0
#
#                                                   genres
# 22866                     [{'id': 35, 'name': 'Comedy'}]  \
# 19359  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 11047                      [{'id': 18, 'name': 'Drama'}]
# 5358   [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 11372  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
#
#                                                 homepage     id    imdb_id
# 22866                                                NaN  77458  tt1735200  \
# 19359                http://theapparition.warnerbros.com  79694  tt1433822
# 11047                                                NaN  17741  tt0426627
# 5358                                                 NaN  43915  tt0061653
# 11372  http://www.newline.com/properties/butterflyeff...  14620  tt0457297
#
#       original_language          original_title
# 22866                fr       Le cochon de Gaza  \
# 19359                en          The Apparition
# 11047                en                  Stoned
# 5358                 en                  Fathom
# 11372                en  The Butterfly Effect 2
#
#                                                 overview  ...    status
# 22866  After a tempest, fishermen do not find only fi...  ...  Released  \
# 19359  Plagued by frightening occurrences in their ho...  ...  Released
# 11047  A chronicle of the sordid life and suspicious ...  ...  Released
# 5358   While touring abroad in Europe, beautiful Amer...  ...  Released
# 11372  After his girlfriend, Julie and two best frien...  ...  Released
#
#                                                  tagline
# 22866                                                NaN  \
# 19359                           Once You Believe You Die
# 11047            The story of the original Rolling Stone
# 5358        The world's most uncovered undercover agent!
# 11372  Can you change your past without destroying yo...
#
#                         title  video vote_average  vote_count
# 22866    When Pigs Have Wings  False          7.1        27.0  \
# 19359          The Apparition  False          4.5       140.0
# 11047                  Stoned  False          5.4        17.0
# 5358                   Fathom  False          7.1         7.0
# 11372  The Butterfly Effect 2  False          4.6       255.0
#
#                        collection_name                             genre
# 22866                             None                            Comedy  \
# 19359                             None                  Horror, Thriller
# 11047                             None                             Drama
# 5358                              None             Action, Comedy, Drama
# 11372  The Butterfly Effect Collection  Drama, Science Fiction, Thriller
#
#                                                  company
# 22866                                        StudioCanal  \
# 19359  StudioCanal, Dark Castle Entertainment, Warner...
# 11047  Wildgaze Films, Number 9 Films, Finola Dwyer P...
# 5358              Twentieth Century Fox Film Corporation
# 11372           New Line Cinema, FilmEngine, BenderSpink
#
#                         country
# 22866  France, Germany, Belgium
# 19359  United States of America
# 11047            United Kingdom
# 5358             United Kingdom
# 11372  United States of America
#
# [5 rows x 28 columns]

# %%
movies['production_countries']= movies['production_countries'].apply(lambda x: 'None' if x == [] else x)
movies['country'] = movies['country'].apply(lambda x: 'None' if x == '' else x)

# %% [markdown]
# *Spoken_languages*

# %%
# Aseguramos que la columna 'spoken_languages' contenga datos JSON válidos
movies['spoken_languages'] = movies['spoken_languages'].apply(lambda x: ast.literal_eval(x) if pd.notnull(x) else 'None')

# Realizamos una función para normalizar la columna "spoken_languages"
def normalize_spoken_languages(languages_list):
    if isinstance(languages_list, list):
        language_names = [language['name'] for language in languages_list]
        return ', '.join(language_names)
    else:
        return 'None'

# Aplicamos la función a cada elemento de la columna 'spoken_languages'
movies['spoken_language'] = movies['spoken_languages'].apply(normalize_spoken_languages)

# Imprimimos movies con la columna de lenguajes normalizada
movies.sample(5)
# Out:
#        adult                              belongs_to_collection budget
# 39466  False  {'id': 53043, 'name': 'The Magick Lantern Cycl...      0  \
# 26039  False  {'id': 135489, 'name': 'Wishmaster Collection'...      0
# 19251  False                                               None      0
# 37462  False                                               None      0
# 21223  False                                               None      0
#
#                                                   genres
# 39466                      [{'id': 18, 'name': 'Drama'}]  \
# 26039  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 19251  [{'id': 9648, 'name': 'Mystery'}, {'id': 53, '...
# 37462                     [{'id': 35, 'name': 'Comedy'}]
# 21223  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#                                homepage      id    imdb_id original_language
# 39466                               NaN   46784  tt0042872                en  \
# 26039                               NaN   28635  tt0254871                en
# 19251  http://www.hierrolapelicula.com/   38256  tt1318025                es
# 37462                               NaN  347669  tt3169832                es
# 21223                               NaN  132064  tt1711018                en
#
#                                original_title
# 39466                           Rabbit's Moon  \
# 26039  Wishmaster 3: Beyond the Gates of Hell
# 19251                                  Hierro
# 37462                             Incidencias
# 21223                                    Vile
#
#                                                 overview  ...
# 39466  Shot in the Films du Panthéon Studio in Paris ...  ...  \
# 26039  The evil Djinn is back at again, this time wre...  ...
# 19251  Traveling on a ferry heading to the island of ...  ...
# 37462  The last train travel of the year from Barcelo...  ...
# 21223  A group of attractive young people (of course)...  ...
#
#                              tagline                                   title
# 39466                            NaN                           Rabbit's Moon  \
# 26039   Three wishes, one nightmare.  Wishmaster 3: Beyond the Gates of Hell
# 19251  A travel. A search. A mystery                                  Hierro
# 37462                            NaN                                Stranded
# 21223            Give Till It Hurts.                                    Vile
#
#        video vote_average vote_count           collection_name
# 39466  False          7.0       10.0  The Magick Lantern Cycle  \
# 26039  False          3.8       38.0     Wishmaster Collection
# 19251  False          6.1       21.0                      None
# 37462  False          5.3       14.0                      None
# 21223  False          4.8       51.0                      None
#
#                    genre                                            company
# 39466              Drama                                               None  \
# 26039   Thriller, Horror  Overseas FilmGroup, GFT Entertainment, Artisan...
# 19251  Mystery, Thriller                  Telecinco Cinema, Madrugada Films
# 37462             Comedy                   Castelao Pictures, Somnium Films
# 21223   Horror, Thriller                                   Tony-Seven Films
#
#                                 country    spoken_language
# 39466          United States of America            English
# 26039  Canada, United States of America            English
# 19251                             Spain  Français, Español
# 37462                             Spain            Español
# 21223          United States of America            English
#
# [5 rows x 29 columns]

# %%
movies['spoken_languages']= movies['spoken_languages'].apply(lambda x: 'None' if x == [] else x)
movies['spoken_language']= movies['spoken_language'].apply(lambda x: 'None' if x == '' else x)

# %% [markdown]
# ## 3. Eliminamos las columnas que no están desanidadas y las que no nos servirán

# %%
creditos.drop(columns=['cast','crew'],inplace=True)
creditos.head()
# Out:
#       id         Director
# 0    862    John Lasseter
# 1   8844     Joe Johnston
# 2  15602    Howard Deutch
# 3  31357  Forest Whitaker
# 4  11862    Charles Shyer

# %%
movies.drop(columns=['belongs_to_collection', 'genres', 'production_companies', 'production_countries', 'spoken_languages', 'video', 'imdb_id', 'adult', 'original_title', 'poster_path', 'homepage',], inplace = True)
movies.head()
# Out:
#      budget     id original_language
# 0  30000000    862                en  \
# 1  65000000   8844                en
# 2         0  15602                en
# 3  16000000  31357                en
# 4         0  11862                en
#
#                                             overview popularity release_date
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943   1995-10-30  \
# 1  When siblings Judy and Peter discover an encha...  17.015539   1995-12-15
# 2  A family wedding reignites the ancient feud be...    11.7129   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...   3.859495   1995-12-22
# 4  Just when George Banks has recovered from his ...   8.387519   1995-02-10
#
#        revenue  runtime    status
# 0  373554033.0     81.0  Released  \
# 1  262797249.0    104.0  Released
# 2          0.0    101.0  Released
# 3   81452156.0    127.0  Released
# 4   76578911.0    106.0  Released
#
#                                              tagline
# 0                                                NaN  \
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  vote_average  vote_count
# 0                    Toy Story           7.7      5415.0  \
# 1                      Jumanji           6.9      2413.0
# 2             Grumpier Old Men           6.5        92.0
# 3            Waiting to Exhale           6.1        34.0
# 4  Father of the Bride Part II           5.7       173.0
#
#                   collection_name                       genre
# 0            Toy Story Collection   Animation, Comedy, Family  \
# 1                            None  Adventure, Fantasy, Family
# 2       Grumpy Old Men Collection             Romance, Comedy
# 3                            None      Comedy, Drama, Romance
# 4  Father of the Bride Collection                      Comedy
#
#                                              company
# 0                            Pixar Animation Studios  \
# 1  TriStar Pictures, Teitler Film, Interscope Com...
# 2                       Warner Bros., Lancaster Gate
# 3             Twentieth Century Fox Film Corporation
# 4         Sandollar Productions, Touchstone Pictures
#
#                     country    spoken_language
# 0  United States of America            English
# 1  United States of America  English, Français
# 2  United States of America            English
# 3  United States of America            English
# 4  United States of America            English

# %% [markdown]
# ## 4. Duplicamos valores para mejorar la consulta de desanidados

# %% [markdown]
# ##### _Observaciones_
# En las columnas desanidas del dataframe "movies", hay algunos valores separados por comas, por ejemplo "genres" que contiene (Animation, Comedy, Family).
# Es por eso que haremos un análsis con valores únicos y posteriormente duplicaremos las filas para que de desagreguen esos valores de cada columna.

# %% [markdown]
# Imprimimos los datos únicos de los datos desanidados y la cantidad de estos

# %%
# Al imprimir los valores únicos, nos damos cuenta que hay valores únicos que contienen a partir de 2 a más características, como lo explicado en genres anteriormente.
print (movies.collection_name.unique())
print(movies.genre.unique())
print(movies.company.unique())
print(movies.country.unique())
print(movies.spoken_language.unique())
# Out:
# ['Toy Story Collection' 'None' 'Grumpy Old Men Collection' ...
#  'Ducobu Collection' 'Mister Blot Collection' 'Red Lotus Collection']
# ['Animation, Comedy, Family' 'Adventure, Fantasy, Family'
#  'Romance, Comedy' ... 'Crime, Comedy, Action, Family'
#  'Action, Mystery, Thriller, Horror' 'Family, Animation, Romance, Comedy']
# ['Pixar Animation Studios'
#  'TriStar Pictures, Teitler Film, Interscope Communications'
#  'Warner Bros., Lancaster Gate' ...
#  'Westdeutscher Rundfunk (WDR), Working Title Films, 20th Century Fox Television, CanWest Global Communications'
#  'Sine Olivia' 'Yermoliev']
# ['United States of America' 'Germany, United States of America'
#  'United Kingdom, United States of America' ...
#  'Poland, Czech Republic, Slovakia' 'Cuba, Germany, Spain'
#  'Egypt, Italy, United States of America']
# ['English' 'English, Français' 'English, Español' ... 'svenska, Deutsch'
#  'العربية, Polski' 'Fulfulde, English']

# %%
# Imprimiremos la cantidad de valores únicos para ver el cambio posteriormente al hacer el duplicado.
print ('Cantidad de collection_name:',movies.collection_name.nunique())
print('Cantidad de genre:',movies.genre.nunique())
print('Cantidad de company:',movies.company.nunique())
print('Cantidad de country:',movies.country.nunique())
print('Cantidad de spoken_language:',movies.spoken_language.nunique())
# Out:
# Cantidad de collection_name: 1696
# Cantidad de genre: 4069
# Cantidad de company: 22671
# Cantidad de country: 2390
# Cantidad de spoken_language: 1842

# %% [markdown]
# Crear registros duplicados

# %%
# Se crearán filas duplicadas ya que al desanidar hay dos datos en una fila, Ejemplo: 'genre', donde algunos tienen 'Animation, Comedy', estos valores se desagregarán.

# Se crean nuevas columnas 
movies['collection_names'] = movies['collection_name'].str.split(', ')
movies['genres'] = movies['genre'].str.split(', ')
movies['companies'] = movies['company'].str.split(', ')
movies['countries'] = movies['country'].str.split(', ')
movies['languages'] = movies['spoken_language'].str.split(', ')

# Se duplican los registros
movies=movies.explode('collection_names').reset_index(drop=True)
movies=movies.explode('genres').reset_index(drop=True)
movies=movies.explode('companies').reset_index(drop=True)
movies=movies.explode('countries').reset_index(drop=True)
movies=movies.explode('languages').reset_index(drop=True)

#Se eliminan las columnas originales
movies.drop('collection_name',axis=1,inplace=True)
movies.drop('genre',axis=1,inplace=True)
movies.drop('company',axis=1,inplace=True)
movies.drop('country',axis=1,inplace=True)
movies.drop('spoken_language',axis=1,inplace=True)

# %%
# Comparamos con el anterior código para ver si hubieron cambios
print (movies.collection_names.unique())
print(movies.genres.unique())
print(movies.companies.unique())
print(movies.countries.unique())
print(movies.languages.unique())
# Out:
# ['Toy Story Collection' 'None' 'Grumpy Old Men Collection' ...
#  'Ducobu Collection' 'Mister Blot Collection' 'Red Lotus Collection']
# ['Animation' 'Comedy' 'Family' 'Adventure' 'Fantasy' 'Romance' 'Drama'
#  'Action' 'Crime' 'Thriller' 'Horror' 'History' 'Science Fiction'
#  'Mystery' 'War' 'Foreign' 'None' 'Music' 'Documentary' 'Western'
#  'TV Movie' 'Carousel Productions' 'Vision View Entertainment'
#  'Telescene Film Group Productions' 'Aniplex' 'GoHands' 'BROSTA TV'
#  'Mardock Scramble Production Committee' 'Sentai Filmworks'
#  'Odyssey Media' 'Pulser Productions' 'Rogue State' 'The Cartel']
# ['Pixar Animation Studios' 'TriStar Pictures' 'Teitler Film' ...
#  'Pirie Productions' 'Sine Olivia' 'Yermoliev']
# ['United States of America' 'Germany' 'United Kingdom' 'France' 'Italy'
#  'Spain' 'China' 'Australia' 'South Africa' 'Canada' 'None' 'Switzerland'
#  'Belgium' 'Japan' 'Iran' 'Netherlands' 'Hong Kong' 'Tunisia' 'Ireland'
#  'Dominican Republic' 'Croatia' 'Russia' 'Macedonia' 'Austria' 'Taiwan'
#  'New Zealand' 'Mexico' 'Poland' 'Peru' 'Cuba' 'Liechtenstein' 'Denmark'
#  'Portugal' 'Finland' 'Sweden' 'Argentina' 'Iceland' 'South Korea'
#  'Serbia' 'Hungary' 'Czech Republic' 'India' 'Brazil' 'Greece' 'Congo'
#  'Senegal' 'Burkina Faso' 'Romania' 'Philippines' 'Vietnam'
#  'Trinidad and Tobago' 'Bulgaria' 'Chile' 'Norway' 'Kazakhstan' 'Algeria'
#  'Luxembourg' 'Georgia' 'Ukraine' 'Botswana' 'Aruba' 'Israel' 'Turkey'
#  'Ecuador' 'Lebanon' 'Morocco' 'Bosnia and Herzegovina' 'Bahamas'
#  'Malaysia' 'Bhutan' 'Jamaica' 'Pakistan' 'Nepal' "Cote D'Ivoire"
#  'Thailand' 'Namibia' 'Cameroon' 'Colombia' 'Czechoslovakia' 'Uruguay'
#  'Slovenia' 'Libyan Arab Jamahiriya' 'Puerto Rico' 'Soviet Union'
#  'East Germany' 'Singapore' 'Afghanistan' 'Malta' 'Panama' 'Egypt'
#  'Zimbabwe' 'Tajikistan' 'Uzbekistan' 'Costa Rica' 'Kuwait' 'Martinique'
#  'Ghana' 'Armenia' 'Indonesia' 'Mongolia' 'Bolivia' 'Monaco' 'Iraq'
#  'Slovakia' 'Serbia and Montenegro' 'Venezuela' 'Lithuania' 'Rwanda'
#  'Palestinian Territory' 'Chad' 'Paraguay' 'Qatar' 'Estonia' 'Macao'
#  'Mali' 'United States Minor Outlying Islands' 'Latvia'
#  'United Arab Emirates' 'Azerbaijan' 'Cayman Islands' 'Nicaragua'
#  'Liberia' 'Yugoslavia' 'Montenegro' 'Angola' 'Belarus' 'Cambodia'
#  'Mauritania' 'Cyprus' 'Bangladesh' 'Syrian Arab Republic'
#  'Kyrgyz Republic' 'Albania' 'Tanzania' 'North Korea' 'Kenya' 'Jordan'
#  'Uganda' 'Saudi Arabia' 'Somalia' 'Guatemala' 'Madagascar' 'Ethiopia'
#  'Sri Lanka' 'Papua New Guinea' 'Nigeria'
#  "Lao People's Democratic Republic" 'French Polynesia'
#  'Netherlands Antilles' 'Myanmar' 'Bermuda' 'El Salvador'
#  'French Southern Territories' 'Samoa' 'Moldova' 'Barbados' 'Antarctica'
#  'Gibraltar' 'Brunei Darussalam' 'Honduras' 'Guinea']
# ['English' 'Français' 'Español' 'Deutsch' 'Pусский' 'Latin' 'Nederlands'
#  '广州话 / 廣州話' '普通话' 'Magyar' 'None' 'shqip' 'Italiano' '한국어/조선말' 'فارسی'
#  'Dansk' '' '日本語' 'العربية' 'Hrvatski' 'Bosanski' 'Română'
#  'Bahasa indonesia' 'Bahasa melayu' 'svenska' 'עִבְרִית' 'Český' 'Polski'
#  'Gaeilge' 'Norsk' 'Slovenčina' 'Tiếng Việt' 'Português' 'हिन्दी' 'Català'
#  'Íslenska' 'Afrikaans' 'Srpski' 'বাংলা' 'Wolof' 'Cymraeg' 'ภาษาไทย'
#  'Latviešu' 'Kiswahili' 'български език' 'ελληνικά' 'Türkçe' 'suomi'
#  'Esperanto' 'Український' 'ქართული' 'Bokmål' 'No Language' 'euskera'
#  'Azərbaycan' 'Malti' 'اردو' 'isiZulu' 'Bamanankan' 'پښتو' 'Somali'
#  'ਪੰਜਾਬੀ' 'беларуская мова' 'தமிழ்' 'Galego' 'Kinyarwanda' 'қазақ' 'Eesti'
#  'Lietuvi\x9akai' 'Slovenščina' 'తెలుగు' 'Fulfulde' '??????' '?????'
#  'ozbek' 'Hausa']

# %%
print ('Cantidad de collection_names:',movies.collection_names.nunique())
print('Cantidad de genres:',movies.genres.nunique())
print('Cantidad de companies:',movies.companies.nunique())
print('Cantidad de countries:',movies.countries.nunique())
print('Cantidad de languages:',movies.languages.nunique())
# Out:
# Cantidad de collection_names: 1721
# Cantidad de genres: 33
# Cantidad de companies: 23567
# Cantidad de countries: 161
# Cantidad de languages: 76

# %%
# Observamos que las filas se duplicaron y se desagregaron los datos separados por comas.
movies.head(10)
# Out:
#      budget    id original_language
# 0  30000000   862                en  \
# 1  30000000   862                en
# 2  30000000   862                en
# 3  65000000  8844                en
# 4  65000000  8844                en
# 5  65000000  8844                en
# 6  65000000  8844                en
# 7  65000000  8844                en
# 8  65000000  8844                en
# 9  65000000  8844                en
#
#                                             overview popularity release_date
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943   1995-10-30  \
# 1  Led by Woody, Andy's toys live happily in his ...  21.946943   1995-10-30
# 2  Led by Woody, Andy's toys live happily in his ...  21.946943   1995-10-30
# 3  When siblings Judy and Peter discover an encha...  17.015539   1995-12-15
# 4  When siblings Judy and Peter discover an encha...  17.015539   1995-12-15
# 5  When siblings Judy and Peter discover an encha...  17.015539   1995-12-15
# 6  When siblings Judy and Peter discover an encha...  17.015539   1995-12-15
# 7  When siblings Judy and Peter discover an encha...  17.015539   1995-12-15
# 8  When siblings Judy and Peter discover an encha...  17.015539   1995-12-15
# 9  When siblings Judy and Peter discover an encha...  17.015539   1995-12-15
#
#        revenue  runtime    status                                    tagline
# 0  373554033.0     81.0  Released                                        NaN  \
# 1  373554033.0     81.0  Released                                        NaN
# 2  373554033.0     81.0  Released                                        NaN
# 3  262797249.0    104.0  Released  Roll the dice and unleash the excitement!
# 4  262797249.0    104.0  Released  Roll the dice and unleash the excitement!
# 5  262797249.0    104.0  Released  Roll the dice and unleash the excitement!
# 6  262797249.0    104.0  Released  Roll the dice and unleash the excitement!
# 7  262797249.0    104.0  Released  Roll the dice and unleash the excitement!
# 8  262797249.0    104.0  Released  Roll the dice and unleash the excitement!
# 9  262797249.0    104.0  Released  Roll the dice and unleash the excitement!
#
#        title  vote_average  vote_count      collection_names     genres
# 0  Toy Story           7.7      5415.0  Toy Story Collection  Animation  \
# 1  Toy Story           7.7      5415.0  Toy Story Collection     Comedy
# 2  Toy Story           7.7      5415.0  Toy Story Collection     Family
# 3    Jumanji           6.9      2413.0                  None  Adventure
# 4    Jumanji           6.9      2413.0                  None  Adventure
# 5    Jumanji           6.9      2413.0                  None  Adventure
# 6    Jumanji           6.9      2413.0                  None  Adventure
# 7    Jumanji           6.9      2413.0                  None  Adventure
# 8    Jumanji           6.9      2413.0                  None  Adventure
# 9    Jumanji           6.9      2413.0                  None    Fantasy
#
#                    companies                 countries languages
# 0    Pixar Animation Studios  United States of America   English
# 1    Pixar Animation Studios  United States of America   English
# 2    Pixar Animation Studios  United States of America   English
# 3           TriStar Pictures  United States of America   English
# 4           TriStar Pictures  United States of America  Français
# 5               Teitler Film  United States of America   English
# 6               Teitler Film  United States of America  Français
# 7  Interscope Communications  United States of America   English
# 8  Interscope Communications  United States of America  Français
# 9           TriStar Pictures  United States of America   English

# %% [markdown]
# ## 5. Valores Nulos

# %% [markdown]
# Los valores nulos de los campos revenue, budget deben ser rellenados por el número 0.

# %%
# Rellenamos los valores faltantes en 'revenue' y 'budget' con el valor 0.
movies['revenue'].fillna(0, inplace=True)
movies['budget'].fillna(0, inplace=True)

# Contamos la cantidad de valores nulos en 'revenue' y 'budget'
print('Valores nulos en revenue',movies['revenue'].isna().sum())
print('Valores nulos en budget',movies['revenue'].isna().sum())
# Out:
# Valores nulos en revenue 0
# Valores nulos en budget 0

# %% [markdown]
# Los valores nulos del campo release date deben eliminarse.

# %%
# Eliminamos las filas con valores nulos de 'realease_date'
movies=movies.dropna(subset=['release_date'])

# Contamos la cantidad de valores nulos en 'realease_date'
print('Valores nulos en realease_date:', movies['release_date'].isna().sum())
# Out:
# Valores nulos en realease_date: 0

# %% [markdown]
# Los valores en la columna "title" del dataframe "movies" cuentan con vacíos

# %%
# Observamos la cantidad de valores en la columna "title"
movies['title'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 422016 entries, 0 to 422194
# Series name: title
# Non-Null Count   Dtype
# --------------   -----
# 422004 non-null  object
# dtypes: object(1)
# memory usage: 6.4+ MB

# %%
# Aplicamos una máscara para verificar valores vacíos
mask = movies['title'] > ''
movies = movies.loc[mask]

# %%
# Observamos que se eliminaron algunos valores vacíos
movies['title'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 422004 entries, 0 to 422194
# Series name: title
# Non-Null Count   Dtype
# --------------   -----
# 422004 non-null  object
# dtypes: object(1)
# memory usage: 6.4+ MB

# %% [markdown]
# ## 6. Modificación de fecha

# %% [markdown]
# De haber fechas, deberán tener el formato AAAA-mm-dd, además deberán crear la columna release_year donde extraerán el año de la fecha de estreno.

# %%
# Transformamos 'release_date' en el formato 'aaaa-mm-dd', en caso el formato sea incorrecto.
movies['release_date'] = pd.to_datetime(movies['release_date'], errors='coerce').dt.strftime('%Y-%m-%d')

# Creamos la columna 'release_year' extrayendo el año de 'release_date'.
movies['release_year'] = pd.to_datetime(movies['release_date'], errors='coerce').dt.year
movies['release_year'] = movies['release_year'].astype('Int64')

# %%
movies[['release_date','release_year']]
# Out:
#        release_date  release_year
# 0        1995-10-30          1995
# 1        1995-10-30          1995
# 2        1995-10-30          1995
# 3        1995-12-15          1995
# 4        1995-12-15          1995
# ...             ...           ...
# 422190   2003-08-01          2003
# 422191   2003-08-01          2003
# 422192   2003-08-01          2003
# 422193   1917-10-21          1917
# 422194   2017-06-09          2017
#
# [422004 rows x 2 columns]

# %%
# Observamos que la columna "release_date" del dataframe "movies" es una fecha pero está en formato objeto.
movies['release_date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 422004 entries, 0 to 422194
# Series name: release_date
# Non-Null Count   Dtype
# --------------   -----
# 422004 non-null  object
# dtypes: object(1)
# memory usage: 6.4+ MB

# %%
# Convertimos la columna "release_date" del dataframe "movies" en formato fecha.
movies['release_date'] = pd.to_datetime(movies['release_date'])

# %%
# Observamos que la columna "release_date" del dataframe "movies" está en formato fecha.
movies['release_date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 422004 entries, 0 to 422194
# Series name: release_date
# Non-Null Count   Dtype
# --------------   -----
# 422004 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 6.4 MB

# %%
# Borramos nulos de 'release_date' y 'release_year'
movies=movies.dropna(subset=['release_date'])
movies=movies.dropna(subset=['release_year'])

# Contamos la cantidad de valores nulos en 'realease_date' y 'release_year'
print('Valores nulos en realease_date:', movies['release_date'].isna().sum())
print('Valores nulos en realease_year:', movies['release_year'].isna().sum())
# Out:
# Valores nulos en realease_date: 0
# Valores nulos en realease_year: 0

# %%
# Observamos la cantidad de nulos del dataframe "movies"
movies.isna().sum()
# Out:
# budget                    0
# id                        0
# original_language        96
# overview               2495
# popularity                0
# release_date              0
# revenue                   0
# runtime                 544
# status                  143
# tagline              193173
# title                     0
# vote_average              0
# vote_count                0
# collection_names          0
# genres                    0
# companies                 0
# countries                 0
# languages                 0
# release_year              0
# dtype: int64

# %%
# Observamos la cantidad de nulos del dataframe "creditos"
creditos.isna().sum()
# Out:
# id            0
# Director    887
# dtype: int64

# %% [markdown]
# ## 7. Creación de columna retorno de inversión

# %% [markdown]
# Crear la columna con el retorno de inversión, llamada return con los campos revenue y budget, dividiendo estas dos últimas revenue / budget, cuando no hay datos disponibles para calcularlo, deberá tomar el valor 0.

# %%
# Convertimos 'revenue' y 'budget' a tipo float
movies['revenue'] = pd.to_numeric(movies['revenue'])
movies['budget'] = pd.to_numeric(movies['budget'])

# Calculamos el retorno de inversión
movies['return'] = movies['revenue'].divide(movies['budget']).replace([np.inf, -np.inf],0).fillna(0)
movies[['return']]
# Out:
#            return
# 0       12.451801
# 1       12.451801
# 2       12.451801
# 3        4.043035
# 4        4.043035
# ...           ...
# 422190   0.000000
# 422191   0.000000
# 422192   0.000000
# 422193   0.000000
# 422194   0.000000
#
# [422004 rows x 1 columns]

# %% [markdown]
# ## 8. Unimos el dataframe "creditos" con "movies"

# %%
# Tienen en común id.
movies.head(2)
# Out:
#      budget   id original_language
# 0  30000000  862                en  \
# 1  30000000  862                en
#
#                                             overview popularity release_date
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943   1995-10-30  \
# 1  Led by Woody, Andy's toys live happily in his ...  21.946943   1995-10-30
#
#        revenue  runtime    status tagline      title  vote_average
# 0  373554033.0     81.0  Released     NaN  Toy Story           7.7  \
# 1  373554033.0     81.0  Released     NaN  Toy Story           7.7
#
#    vote_count      collection_names     genres                companies
# 0      5415.0  Toy Story Collection  Animation  Pixar Animation Studios  \
# 1      5415.0  Toy Story Collection     Comedy  Pixar Animation Studios
#
#                   countries languages  release_year     return
# 0  United States of America   English          1995  12.451801
# 1  United States of America   English          1995  12.451801

# %%
# Tienen en común id.
creditos.head(1)
# Out:
#     id       Director
# 0  862  John Lasseter

# %%
# Convertimos la columna 'id' de "creditos" y "movies" a tipo int64 para que coincidan entre ambos.
creditos['id'] = creditos['id'].astype('int64')
movies['id'] = movies['id'].astype('int64')

# Unimos los dataframes en función de la columna 'id', creando un nuevo dataframe "datos".
datos = pd.merge(movies, creditos, on='id')

# %%
# Observamos que los datos se hayan unido.
datos.sample(3)
# Out:
#         budget      id original_language
# 50295   100000   11713                zh  \
# 54199        0    9028                it
# 401508       0  300438                et
#
#                                                  overview popularity
# 50295   Chen Zhen returns to the international compoun...   9.523138  \
# 54199   A mute gunslinger fights in the defense of a g...   3.237317
# 401508  Young and active nationalist Aleksander Keskül...    0.33279
#
#        release_date  revenue  runtime    status
# 50295    1972-03-22      0.0    108.0  Released  \
# 54199    1968-02-21      0.0    100.0  Released
# 401508   1997-10-02      0.0     99.0  Released
#
#                                                   tagline  ... vote_average
# 50295   Bruce Lee has done the impossible... ...HE'S S...  ...          7.4  \
# 54199                 His voice was the silence of death!  ...          7.5
# 401508                                                NaN  ...          6.0
#
#         vote_count  collection_names    genres               companies
# 50295        164.0              None    Action  Golden Harvest Company  \
# 54199         58.0              None   Western        Les Films Corona
# 401508         1.0              None  Thriller              Faama Film
#
#         countries languages release_year  return         Director
# 50295   Hong Kong       普通话         1972     0.0           Lo Wei
# 54199      France  Italiano         1968     0.0  Sergio Corbucci
# 401508     Russia   English         1997     0.0     Hardi Volmer
#
# [3 rows x 21 columns]

# %%
# Observamps los datos vacíos del nuevo datarframe "datos".
datos.isna().sum()
# Out:
# budget                    0
# id                        0
# original_language        96
# overview               2495
# popularity                0
# release_date              0
# revenue                   0
# runtime                 544
# status                  143
# tagline              195330
# title                     0
# vote_average              0
# vote_count                0
# collection_names          0
# genres                    0
# companies                 0
# countries                 0
# languages                 0
# release_year              0
# return                    0
# Director               1512
# dtype: int64

# %%
# Cambiamos los datos nulos del dataframe por 'None'.
datos = datos.where(pd.notna(datos), 'None')

# %%
# Verificamos que los datos estén parejos.
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 424431 entries, 0 to 424430
# Data columns (total 21 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   budget             424431 non-null  int64
#  1   id                 424431 non-null  int64
#  2   original_language  424431 non-null  object
#  3   overview           424431 non-null  object
#  4   popularity         424431 non-null  object
#  5   release_date       424431 non-null  datetime64[ns]
#  6   revenue            424431 non-null  float64
#  7   runtime            424431 non-null  object
#  8   status             424431 non-null  object
#  9   tagline            424431 non-null  object
#  10  title              424431 non-null  object
#  11  vote_average       424431 non-null  float64
#  12  vote_count         424431 non-null  float64
#  13  collection_names   424431 non-null  object
#  14  genres             424431 non-null  object
#  15  companies          424431 non-null  object
#  16  countries          424431 non-null  object
#  17  languages          424431 non-null  object
#  18  release_year       424431 non-null  Int64
#  19  return             424431 non-null  float64
#  20  Director           424431 non-null  object
# dtypes: Int64(1), datetime64[ns](1), float64(4), int64(2), object(13)
# memory usage: 68.4+ MB

# %% [markdown]
# ## 9. Exportamos el dataframe "datos" a un archivo .csv

# %%
# Obtenemos el archivo con el ETL aplicado
datos.to_csv("datos_finales.csv", index=False)

# %% [markdown]
# ## 10. Realizamos un dataset con los valores necesarios para las consultas en la API y el Modelo de recomendación

# %%
# Realizaremos un dataset con los valores necesarios ya que el peso del último dataset exportado es muy grande.
# Leemos el dataset "datos".
datos = pd.read_csv('datos_finales.csv', sep=',')

# %%
datos.head(2)
# Out:
#      budget   id original_language
# 0  30000000  862                en  \
# 1  30000000  862                en
#
#                                             overview  popularity release_date
# 0  Led by Woody, Andy's toys live happily in his ...   21.946943   1995-10-30  \
# 1  Led by Woody, Andy's toys live happily in his ...   21.946943   1995-10-30
#
#        revenue  runtime    status tagline  ... vote_average  vote_count
# 0  373554033.0     81.0  Released     NaN  ...          7.7      5415.0  \
# 1  373554033.0     81.0  Released     NaN  ...          7.7      5415.0
#
#        collection_names     genres                companies
# 0  Toy Story Collection  Animation  Pixar Animation Studios  \
# 1  Toy Story Collection     Comedy  Pixar Animation Studios
#
#                   countries languages release_year     return       Director
# 0  United States of America   English         1995  12.451801  John Lasseter
# 1  United States of America   English         1995  12.451801  John Lasseter
#
# [2 rows x 21 columns]

# %%
columnas=['id','budget','original_language','popularity','release_date','revenue','runtime','title', 'vote_average', 'vote_count', 'collection_names', 'genres', 'companies', 'countries', 'languages', 'release_year', 'return', 'Director' ]

# %%
data_movies= datos[columnas]

# %%
data_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 424431 entries, 0 to 424430
# Data columns (total 18 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 424431 non-null  int64
#  1   budget             424431 non-null  int64
#  2   original_language  424335 non-null  object
#  3   popularity         424431 non-null  float64
#  4   release_date       424431 non-null  object
#  5   revenue            424431 non-null  float64
#  6   runtime            423887 non-null  float64
#  7   title              424431 non-null  object
#  8   vote_average       424431 non-null  float64
#  9   vote_count         424431 non-null  float64
#  10  collection_names   55238 non-null   object
#  11  genres             421287 non-null  object
#  12  companies          397322 non-null  object
#  13  countries          413069 non-null  object
#  14  languages          411960 non-null  object
#  15  release_year       424431 non-null  int64
#  16  return             424431 non-null  float64
#  17  Director           422919 non-null  object
# dtypes: float64(6), int64(3), object(9)
# memory usage: 58.3+ MB

# %%
data_movies.to_csv("datos_main.csv", index=False)
